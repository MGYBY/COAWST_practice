# %%
import xarray as xr
import numpy as np
import pandas as pd

# %%
era5_data = xr.open_dataset(r'./output.nc')
era5_data
# Out:
# <xarray.Dataset> Size: 24MB
# Dimensions:  (lat: 1321, lon: 4621)
# Coordinates:
#   * lat      (lat) float64 11kB 43.15 43.15 43.15 43.15 ... 44.25 44.25 44.25
#   * lon      (lon) float64 37kB -79.9 -79.9 -79.9 -79.9 ... -76.05 -76.05 -76.05
# Data variables:
#     crs      |S1 1B ...
#     Band1    (lat, lon) float32 24MB ...
# Attributes:
#     GDAL_AREA_OR_POINT:  Area
#     Conventions:         CF-1.5
#     GDAL:                GDAL 3.4.1, released 2021/12/27
#     history:             Sun Jan 05 14:46:11 2025: GDAL CreateCopy( output.nc...

# %%
era5_data = era5_data.rename({'Band1':'z'})
# era5_data = era5_data.rename({'lon':'topo_lon'})
# era5_data = era5_data.rename({'lat':'topo_lat'})
# era5_data.assign(lon=era5_data["topo_lon"])
# era5_data.assign(lat=era5_data["topo_lat"])
era5_data.z.values[np.isnan(era5_data.z.values)] = 2.50

# %%
new_filename_2 = './result_2.nc'
print ('saving to ', new_filename_2)
era5_data.to_netcdf(path=new_filename_2)
# Out:
# saving to  ./result_2.nc

# %%
# cdo setmisstonn result_2.nc result_2_mod.nc

# %%
roms_grid = xr.open_dataset(r'./grid_3D.nc')

roms_grid['tra_lon'] = -77.975
roms_grid['tra_lat'] = 43.7
roms_grid['rot'] = 0.0

# roms_grid.center_lon.values = -77.975
# roms_grid.center_lat.values = 43.7

roms_grid.to_netcdf(path='./grid_3D_mod.nc')
